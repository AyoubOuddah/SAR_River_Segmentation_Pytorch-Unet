# %%
pip install pydensecrf
# Out:
# ...
#      |████████████████████████████████| 1.0MB 3.4MB/s
# ...
#   Created wheel for pydensecrf: filename=pydensecrf-1.0rc3-cp36-cp36m-linux_x86_64.whl size=2153755 sha256=9c7418abe08c487d5df007990ac545a9b4b74a5ea36b33e7766a607065d983bc
#   Stored in directory: /root/.cache/pip/wheels/92/6f/ec/5c49c25de8c42c872de50ff53582ba3ead850ce52a81e73ac7
# Successfully built pydensecrf
# ...

# %%
cd SAR_River_Segmentation_Pytorch-Unet/src
# Out:
# /content/SAR_River_Segmentation_Pytorch-Unet/src

# %% [markdown]
# **Training the model**

# %%
# !python train.py --epochs 100 --batch-size 4 --learning-rate 0.001 --scale 1  -W 84.80535260662717
# Out:
# INFO: Using device cuda
# INFO: Network:
# 	2 input channels
# 	1 output channels (classes)
# 	Bilinear upscaling
# INFO: Creating dataset with 1760 examples
# INFO: Starting training:
#         Epochs:          10
#         Batch size:      4
#         Learning rate:   0.0001
#         Training size:   1584
#         Validation size: 176
#         Checkpoints:     True
#         Device:          cuda
#         Images scaling:  1.0
#
# Epoch 1/10:  11% 176/1584 [00:26<03:13,  7.27img/s, loss (batch)=28.1]
# Validation round:   0% 0/176 [00:00<?, ?img/s]
#                                               INFO: Validation Dice Coeff: 0.9884139248585172
# Epoch 1/10:  22% 352/1584 [01:07<02:45,  7.45img/s, loss (batch)=14.2]
# Validation round:   0% 0/176 [00:00<?, ?img/s]
#                                               INFO: Validation Dice Coeff: 0.9884139248585172
# Epoch 1/10:  33% 528/1584 [01:43<02:19,  7.57img/s, loss (batch)=3.46]
# Validation round:   0% 0/176 [00:00<?, ?img/s]
# ...

# %%
# !python train.py --epochs 10 --batch-size 4 --scale 1 --learning-rate 0.0001 --load ./model_checkpoints/CP_epoch_5.pth -W 84.80535260662717
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory
